# %%
import pandas as pd

# 시군구명	접근성 변수명	x좌표	y좌표

bus22= pd.read_csv('2022년_전국버스정류장 위치정보_데이터.csv', encoding = 'utf-8')

bus22 = bus22[['도시명','관리도시명','정류장명','위도','경도']]

# %%
print(bus22['관리도시명'].value_counts())
# Out:
# 관리도시명
# 경기도     44539
# 공단광역    39890
# 서울      12943
# 인천       6526
# 대구       5123
# 경산       4539
# 제주       4086
# 울산       3757
# 목포       3199
# 청주       3141
# 광주       3133
# 원주       3081
# 대전       3033
# 창원       2973
# 전주       2817
# 공주       2798
# 세종       2757
# 칠곡       2534
# 김해       2425
# 천안       2404
# 양산       2284
# 순천       2248
# 아산       2137
# 구미       2131
# 영천       2041
# 서산       2002
# 영덕       1958
# 충주       1933
# 포항       1923
# 여수       1885
# 진주       1845
# 경주       1844
# 광양       1775
# 제천       1764
# 춘천       1733
# 군산       1717
# 김천       1416
# 거제       1277
# 남원       1174
# 함평       1120
# 보은       1049
# 옥천       1001
# 밀양        921
# 사천        826
# 계룡        307
# Name: count, dtype: int64

# %%
경남 = ['김해','창원','의령','산청', '김해시','창원시','의령군','산청군']

# %%
bus22 = bus22[bus22['관리도시명'].isin(경남)]

# %%
print(bus22['관리도시명'].value_counts())
# Out:
# 관리도시명
# 창원    2973
# 김해    2425
# Name: count, dtype: int64

# %%
bus23 = pd.read_csv('2023년_전국버스정류장 위치정보_데이터.csv', encoding = 'cp949')

bus23
# Out:
#                정류장번호    정류장명         위도          경도       정보수집일   모바일단축번호  \
# 0       ADB354000076    신덕1리  36.524325  128.830926  2023-10-16  540076.0
# 1       ADB354000077      나천  36.484444  128.876390  2023-10-16  540077.0
# 2       ADB354000078     골삽실  36.462248  128.887606  2023-10-16  540078.0
# 3       ADB354000079  금곡(길안)  36.394360  128.933281  2023-10-16  540079.0
# 4       ADB354000080   대사.토일  36.368580  128.940353  2023-10-16  540080.0
# ...              ...     ...        ...         ...         ...       ...
# 204204  USB196066514  새진흥아파트  35.540264  129.106553  2023-10-16   66514.0
# 204205  USB196066515    부일맨션  35.539081  129.104984  2023-10-16   66515.0
# 204206  USB196066516    부일맨션  35.539203  129.104913  2023-10-16   66516.0
# 204207  USB196066601   석남유치원  35.562269  129.116000  2023-10-16   66601.0
# 204208  USB196066603    부산은행  35.557706  129.118750  2023-10-16   66603.0
#
#          도시코드       도시명 관리도시명
# 0       37040  경상북도 안동시    안동
# ...

# %%
bus23 = bus23[['도시명','관리도시명','정류장명','위도','경도']]

bus23
# Out:
#              도시명 관리도시명    정류장명         위도          경도
# 0       경상북도 안동시    안동    신덕1리  36.524325  128.830926
# 1       경상북도 안동시    안동      나천  36.484444  128.876390
# 2       경상북도 안동시    안동     골삽실  36.462248  128.887606
# 3       경상북도 안동시    안동  금곡(길안)  36.394360  128.933281
# 4       경상북도 안동시    안동   대사.토일  36.368580  128.940353
# ...          ...   ...     ...        ...         ...
# 204204     울산광역시    울산  새진흥아파트  35.540264  129.106553
# 204205     울산광역시    울산    부일맨션  35.539081  129.104984
# 204206     울산광역시    울산    부일맨션  35.539203  129.104913
# 204207     울산광역시    울산   석남유치원  35.562269  129.116000
# 204208     울산광역시    울산    부산은행  35.557706  129.118750
#
# [204209 rows x 5 columns]

# %%
print(bus23['관리도시명'].value_counts())
# Out:
# 관리도시명
# 경기       45031
# TSBIS    42653
# 부산        9560
# 인천        6587
# 대구        5693
# 경산        4564
# 광주        4261
# 제주        4112
# 울산        3791
# 창원        3333
# 안동        3270
# 청주        3209
# 원주        3098
# 대전        3064
# 전주        2883
# 공주        2843
# 세종        2799
# 목포        2620
# 칠곡        2534
# 김해        2521
# 천안        2439
# 양산        2309
# 순천        2264
# 아산        2168
# 나주        2136
# 구미        2098
# 영천        2057
# 서산        2002
# 영덕        1961
# 포항        1954
# 충주        1952
# 여수        1911
# 경주        1901
# 진주        1824
# 광양        1798
# 제천        1790
# 춘천        1758
# 군산        1732
# 김천        1423
# 거제        1298
# 남원        1178
# 함평        1120
# 보은        1049
# 옥천        1001
# 밀양         931
# 사천         862
# 곡성         560
# 계룡         307
# Name: count, dtype: int64

# %%
bus23 = bus23[bus23['관리도시명'].isin(경남)]

bus23
# Out:
#             도시명 관리도시명       정류장명         위도          경도
# 10276  경상남도 창원시    창원     구암고등학교  35.246296  128.593978
# 10277  경상남도 창원시    창원      사격장입구  35.244923  128.683156
# 10278  경상남도 창원시    창원  장애인복지회관입구  35.244960  128.673597
# 10279  경상남도 창원시    창원  장애인복지회관입구  35.244773  128.673243
# 10280  경상남도 창원시    창원       지귀상가  35.244778  128.659437
# ...         ...   ...        ...        ...         ...
# 55039  경상남도 김해시    김해      성심유치원  35.239390  128.685800
# 55040  경상남도 김해시    김해    창원의집 입구  35.242660  128.680600
# 55041  경상남도 김해시    김해        사림동  35.244240  128.675800
# 55042  경상남도 김해시    김해  장애인복지회관입구  35.245020  128.673400
# 55043  경상남도 김해시    김해     봉곡상가입구  35.245850  128.670800
#
# [5854 rows x 5 columns]

# %%
print(bus23['관리도시명'].value_counts())
# Out:
# 관리도시명
# 창원    3333
# 김해    2521
# Name: count, dtype: int64

# %%
#전국 주차장

pk = pd.read_csv('전국주차장정보표준데이터.csv', encoding = 'cp949')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3316\502273643.py:3: DtypeWarning: Columns (20,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   pk = pd.read_csv('전국주차장정보표준데이터.csv', encoding = 'cp949')

# %%
pk
# Out:
#             주차장관리번호                     주차장명 주차장구분 주차장유형  \
# 0      341-2-000056              법성매립지 제5주차장    공영    노외
# 1      341-2-000057              법성매립지 제6주차장    공영    노외
# 2      341-2-000058              법성매립지 제7주차장    공영    노외
# 3      341-2-000059              법성매립지 제8주차장    공영    노외
# 4      341-2-000060              법성매립지 제9주차장    공영    노외
# ...             ...                      ...   ...   ...
# 16425  298-2-000042       고덕면 대천1리 1지구 공영주차장    공영    노외
# 16426  298-2-000043             태성빌딩 뒤 공영주차장    공영    노외
# 16427  298-2-000044  예산읍 예산리 공영주차장(구 중앙극장 뒤)    공영    노외
# 16428  298-2-000045       고덕면 대천1리 2지구 공영주차장    공영    노외
# 16429  368-2-000001              제1주차장(구경찰서)    공영    노외
#
#                       소재지도로명주소                  소재지지번주소  주차구획수 급지구분 부제시행구분  \
# 0                          NaN  전라남도 영광군 법성면 법성리 1226-4     20   기타    미시행
# 1                          NaN  전라남도 영광군 법성면 법성리 1217-6     40   기타    미시행
# ...

# %%
print(pk.columns)

pk = pk[['제공기관명','주차장명','위도', '경도',]]

pk
# Out:
# Index(['주차장관리번호', '주차장명', '주차장구분', '주차장유형', '소재지도로명주소', '소재지지번주소', '주차구획수',
#        '급지구분', '부제시행구분', '운영요일', '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각',
#        '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금',
#        '추가단위시간', '추가단위요금', '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '결제방법', '특기사항',
#        '관리기관명', '전화번호', '위도', '경도', '장애인전용주차구역보유여부', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')
#           제공기관명                     주차장명         위도          경도
# 0      전라남도 영광군              법성매립지 제5주차장        NaN         NaN
# 1      전라남도 영광군              법성매립지 제6주차장        NaN         NaN
# 2      전라남도 영광군              법성매립지 제7주차장        NaN         NaN
# 3      전라남도 영광군              법성매립지 제8주차장        NaN         NaN
# 4      전라남도 영광군              법성매립지 제9주차장        NaN         NaN
# ...         ...                      ...        ...         ...
# 16425  충청남도 예산군       고덕면 대천1리 1지구 공영주차장  36.745372  126.704497
# ...

# %%
pk_li = pk['제공기관명'].to_list()

# %%
시군구명 = []

for i in pk_li:
    if len(i.split())>=2:
        시군구명.append(i.split()[1])
    else:
        시군구명.append(i.split()[0])

# %%
pk['시군구명'] = 시군구명
# pk = pk.drop('제공기관명',axis = 1)

# %%
# print(pk['시군구명'].value_counts())

pk = pk[pk['시군구명'].isin(경남)]

pk
# Out:
#                     주차장명         위도          경도 시군구명
# 585           의령 복개천 주차장  35.318403  128.263646  의령군
# 1677       의령향교-의령택시 주차장  35.321617  128.258065  의령군
# 1678   서동농협-상동우수저류시설 주차장  35.321078  128.259891  의령군
# 1679      자굴산슈퍼-수정식당 주차장  35.321782  128.262647  의령군
# 1899       굴암산 등산로 제2주차장  35.177519  128.785661  김해시
# ...                  ...        ...         ...  ...
# 12060           백산마을 주차장  35.431821  128.377777  의령군
# 12061           사현마을 주차장  35.474022  128.264453  의령군
# 12062           성당마을 주차장  35.363591  128.389512  의령군
# 12063           오천마을 주차장  35.387620  128.396221  의령군
# 12064           웅곡마을 주차장  35.386419  128.404653  의령군
#
# [268 rows x 4 columns]

# %%
print(pk['시군구명'].value_counts())
# Out:
# 시군구명
# 의령군    96
# 김해시    94
# 창원시    56
# 산청군    22
# Name: count, dtype: int64

# %%
sub = pd.read_csv('전체_도시철도역사정보_20250417.csv')

sub['역사도로명주소']
# Out:
# 0                인천시 남동구 석정로 522-14
# 1                서울시 구로구 경인로 40길 47
# 2                   서울시 구로구 구일로 133
# 3                   인천시 동구 참외전로 245
# 4                 인천시 남구 숙골로 24번길 9
#                    ...
# 1082    대전광역시 서구 문정로48번길 지하 19(탄방동)
# 1083       대전광역시 동구 옥천로 지하162 (판암동)
# 1084     대전광역시 유성구 현충원로 지하 455(구암동)
# 1085       경기도 남양주 다산중앙로 123번길(다산동)
# 1086         경기도 남양주시 경춘북로 375(별내동)
# Name: 역사도로명주소, Length: 1087, dtype: object

# %%
sub_li = sub['역사도로명주소'].to_list()

sub_li
# Out:
# ['인천시 남동구 석정로 522-14',
#  '서울시 구로구 경인로 40길 47',
#  '서울시 구로구 구일로 133',
#  '인천시 동구 참외전로 245',
#  '인천시 남구 숙골로 24번길 9',
#  '인천시 부평구 동암광장로 10',
#  '인천시 중구 참외전로 119',
#  '인천시 부평구 마장로 55번길 14',
#  '인천시 부평구 수변로 22',
#  '경기도 부천시 소사구 부천로 1',
#  '인천시 부평구 광장로 16',
#  '경기도 부천시 소사구 경인로 363',
#  '경기도 부천시 소사구 송내대로 43',
#  '경기도 부천시 원미구 역곡로 1(역곡동)',
#  '서울시 구로구 경인로 20길 13',
#  '서울시 구로구 부일로 872',
#  '인천시 중구 제물량로 269',
#  '인천시 남구 경인로 129',
#  '인천시 남구 주안로 95-19',
#  '경기도 부천시 소사구 중동로 73',
#  '서울특별시 송파구 송파대로 지하257(가락동)',
#  '서울특별시 종로구 사직로 지하130(적선동)',
#  '서울특별시 송파구 중대로 지하149(가락동)',
#  '서울특별시 서초구 신반포로 지하188(반포동)',
#  '서울특별시 서초구 서초대로 지하294(서초동)',
#  '서울특별시 은평구 진관2로 지하15-25 (진관동)',
#  '서울특별시 성동구 동호로 지하104(금호동4가)',
#  '서울특별시 서초구 서초중앙로 지하31(서초동)',
#  '서울특별시 은평구 통일로 지하602-1(녹번동)',
#  '서울특별시 강남구 일원로 지하2(일원동)',
#  '서울특별시 강남구 남부순환로 지하2952(대치동)',
#  '서울특별시 강남구 남부순환로 지하2814(도곡동)',
#  '서울특별시 서대문구 통일로 지하247(현저동)',
#  '서울특별시 중구 동호로 지하256(장충동2가)',
#  '서울특별시 강남구 남부순환로 지하2744(도곡동)',
#  '서울특별시 서대문구 통일로 지하361(홍제동)',
# ...

# %%
pip install selenium beautifulsoup4
# Out:
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# ...
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.4 MB 985.5 kB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.4 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.4 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.4 MB 1.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.6/9.4 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.4 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.4 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 3.7/9.4 MB 1.8 MB/s eta 0:00:04
# ...

# %%
# !pip install selenium beautifulsoup4
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
산청 = set(['구아마을','신아마을','가현마을','원기','구평','왕대마을','노은','갈전마을','묵고가을','중암','화촌','어서리','가림','관이','물산','장재','매곡','임촌','운곡','향양마을','사평마을','부리마을','외부마을','주상마을','자혜마을','상촌마을','석대','고마정','문대','생비량면',
         '방골마을','월곡마을','내곡-월곡','노은마을','특리마을','매곡','임촌','운곡','수산마을','양촌','신기','실매','상중','중촌마을','단성','장란','방동마을','벽계마을','내고마을','외고리','외고','외고마을','양전','수월','수월마을','안봉마을','송정마을','농협앞','손항','우사',
         '철수','중암','창안','장란','내평','신기','중매','신연','생림','진태','자신','진태마을','하양','평촌마을','향양=신정','월평','야정','수대','신기-수대','내곡','양촌','봉두','외송','단계','한빈','내고마을','척지마을','오휴마을','하촌','노은','노은마을','수산마을',
         '차탄','장박마을','내북마을','수청','어은동','고촌마을','송계','단성','내수','금서','시매','쌍효마을','신아','산청약소시장','상중','묵하마을','묵하','구평','관동','점촌','간공','상능','하능마을','갈전마을','생초시외버스정류소','강누리','강누','갈티마을','가실','구사마을','배양','병정','궁소',
         '동의보감촌','소귀마을','물산','법평','율현','둔철마을','덕산동','도선-어은','송계','창평','모고마을','압수마을','매촌마을','대현마을','삼거','양촌-음촌','겁내골휴게소','산골농장','단계','산청초등학교','산청약초시장','가림',
         '연산마을','모례','보건의료원','명동','수월','관이','방목리','법서','신안','방목','청현마을','안봉마을','복지회관','단성중고교','산골농장','둔철생태체험숲','원지정류소','범학','입상마을','안봉마을','수월마을','진태마을','후천-수산','회동','신촌'])


산청_li = list(산청)
print(len(산청_li))

산청_li = ",".join(산청_li)
# Out:
# 146

# %%
with open('산청군 버스정류장이름.txt','w', encoding = 'utf-8') as f:
    f.write(산청_li)

# %%
import pandas as pd

산청bus = pd.read_csv('산청군 버스정류장이름.csv',encoding = 'utf-8')
산청bus
# Out:
#            변수명         위도          경도
# 0         외부마을  35.416752  127.897085
# 1         향양마을  35.410898  127.832699
# 2           모례  35.463494  127.969346
# 3           구평  35.641400  127.859451
# 4    생초시외버스정류소  35.492044  127.832781
# ..         ...        ...         ...
# 125         양전  35.454832  128.028516
# 126      보건의료원  35.415710  127.883766
# 127         상중  35.485339  127.929918
# 128         화촌  35.498144  127.838486
# 129         송계  35.382874  128.078079
#
# [130 rows x 3 columns]

# %%
시군구 = []

for i in range(130):
    시군구.append('산청군')

산청bus['시군구'] = 시군구

산청bus
# Out:
#            변수명         위도          경도  시군구
# 0         외부마을  35.416752  127.897085  산청군
# 1         향양마을  35.410898  127.832699  산청군
# 2           모례  35.463494  127.969346  산청군
# 3           구평  35.641400  127.859451  산청군
# 4    생초시외버스정류소  35.492044  127.832781  산청군
# ..         ...        ...         ...  ...
# 125         양전  35.454832  128.028516  산청군
# 126      보건의료원  35.415710  127.883766  산청군
# 127         상중  35.485339  127.929918  산청군
# 128         화촌  35.498144  127.838486  산청군
# 129         송계  35.382874  128.078079  산청군
#
# [130 rows x 4 columns]

# %%
의령bus = pd.read_csv('의령군 버스정류장 정보.csv',encoding = 'utf-8')

의령bus
# Out:
#             변수명         위도          경도
# 0            가례  35.323882  128.243071
# 1          걔현2구  35.461935  128.251115
# 2          계현입구  35.431759  128.268696
# 3           구송산  35.420201  128.286022
# 4           구오목  35.399975  128.278603
# 5          군민회관  35.318166  128.264685
# 6       군북버스터미널  35.263606  128.343491
# 7         군북터미널  35.264769  128.343470
# 8       궁류-석정마을  35.447951  128.248488
# 9          궁류시장  35.439324  128.250312
# 10      남지버스터미널  35.391683  128.484119
# 11        농어촌공사  35.367125  128.261524
# 12         다현마을  35.463095  128.251445
# 13         당동마을  35.453924  128.246436
# 14           대산  35.285227  128.288806
# 15           두호  35.339513  128.382883
# 16           막곡  35.464672  128.333721
# 17           매곡  35.661749  129.355540
# 18           무전  35.525089  128.307595
# 19           봉두  35.063416  127.582371
# 20      봉두마을-역들  35.334301  128.215641
# 21  불양암-오암마을-암하  35.368672  128.321972
# 22         산학마을  35.350062  128.299272
# ...

# %%
시군구  = ['의령군' for i in range(0,57)]

의령bus['시군구'] = 시군구
의령bus
# Out:
#             변수명         위도          경도  시군구
# 0            가례  35.323882  128.243071  의령군
# 1          걔현2구  35.461935  128.251115  의령군
# 2          계현입구  35.431759  128.268696  의령군
# 3           구송산  35.420201  128.286022  의령군
# 4           구오목  35.399975  128.278603  의령군
# 5          군민회관  35.318166  128.264685  의령군
# 6       군북버스터미널  35.263606  128.343491  의령군
# 7         군북터미널  35.264769  128.343470  의령군
# 8       궁류-석정마을  35.447951  128.248488  의령군
# 9          궁류시장  35.439324  128.250312  의령군
# 10      남지버스터미널  35.391683  128.484119  의령군
# 11        농어촌공사  35.367125  128.261524  의령군
# 12         다현마을  35.463095  128.251445  의령군
# 13         당동마을  35.453924  128.246436  의령군
# 14           대산  35.285227  128.288806  의령군
# 15           두호  35.339513  128.382883  의령군
# 16           막곡  35.464672  128.333721  의령군
# 17           매곡  35.661749  129.355540  의령군
# 18           무전  35.525089  128.307595  의령군
# 19           봉두  35.063416  127.582371  의령군
# ...

# %%
의령bus.to_csv('의령군 버스정류장 정보.csv', encoding = 'utf-8')
산청bus.to_csv('산청 버스정류장 정보.csv', encoding = 'utf-8')
